# %% [markdown]
# # cGRU; Var(2); T = 1000

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://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@github.com/Proton1121/ngcausality.git
# Out:
# Cloning into 'ngcausality'...
# remote: Enumerating objects: 261, done.
# remote: Counting objects: 100% (76/76), done.
# remote: Compressing objects: 100% (68/68), done.
# remote: Total 261 (delta 54), reused 8 (delta 8), pack-reused 185 (from 1)
# Receiving objects: 100% (261/261), 2.80 MiB | 22.92 MiB/s, done.
# Resolving deltas: 100% (130/130), done.

# %%
# %cd /content/ngcausality
# Out:
# /content/ngcausality

# %%
import os
import torch
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from data.synthetic import simulate_lorenz_96, simulate_var
from data.dream import generate_causal_matrix
from models.cgru import cGRU, train_model_ista

# %%
save_dir = '/content/drive/MyDrive/ngcausality_results/' + 'cgru_var2_t1000/'

if not os.path.exists(save_dir):
    os.makedirs(save_dir)

# %%
# For GPU acceleration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
# Simulate data
X_np, beta, GC = simulate_var(p=20, T=1000, lag=2)
X = torch.tensor(X_np[np.newaxis], dtype=torch.float32, device=device)

# %%
# Save the simulated data to Google Drive
np.save(os.path.join(save_dir, 'X_np.npy'), X_np)  # Save X_np (simulated data)
np.save(os.path.join(save_dir, 'GC.npy'), GC)  # Save GC (Granger causality matrix)

torch.save(X, os.path.join(save_dir, 'X_tensor.pt'))

with open(os.path.join(save_dir, 'data_shapes.txt'), 'w') as f:
    f.write(f'Shape of X_np: {X_np.shape}\n')
    f.write(f'Shape of GC: {GC.shape}\n')
    f.write(f'Shape of X (torch tensor): {X.shape}\n')

# %%
# Plot data
fig, axarr = plt.subplots(1, 2, figsize=(16, 5))
axarr[0].plot(X_np)
axarr[0].set_xlabel('T')
axarr[0].set_title('Entire time series')
axarr[1].plot(X_np[:50, :5])
axarr[1].set_xlabel('T')
axarr[1].set_title('First 50 time points for the first 5 variables')
plt.tight_layout()


# Step 5: Save the plot to Google Drive
plot_filename = os.path.join(save_dir, 'data_plots.png')
plt.savefig(plot_filename)  # Save the plot as a PNG file in Google Drive

# Optionally, close the plot to prevent it from displaying in the notebook (you can skip this if you want to see it in the notebook)
plt.close()

# %%
for i in range(20):
  save_dir = '/content/drive/MyDrive/ngcausality_results/' + 'cgru_var2_t1000/' + str(0.016 + 0.008 * (1+i)) + '/'

  if not os.path.exists(save_dir):
    os.makedirs(save_dir)

  #Set up model
  cgru = cGRU(X.shape[-1], hidden=100).to(device=device)

  # Train with ISTA
  train_loss_list = train_model_ista(cgru, X, context=10, lr=1e-2, max_iter=20000, lam=(0.016 + 0.008 * (1+i)), lam_ridge=1e-3,
                   check_every=50)

  # Loss function plot
  plt.figure(figsize=(8, 5))
  train_loss_np = [loss.cpu().detach().numpy() for loss in train_loss_list]
  plt.plot(50 * np.arange(len(train_loss_np)), train_loss_np)
  plt.title('cGRU training')
  plt.ylabel('Loss')
  plt.xlabel('Training steps')
  plt.tight_layout()
  loss_plot_path = os.path.join(save_dir, f'loss_plot_{0.016 + 0.008 * (1+i)}.png')
  plt.savefig(loss_plot_path)  # Save the loss plot to Google Drive
  plt.close()  # Close the plot to prevent it from displaying

  # Verify learned Granger causality
  GC_est = cgru.GC().cpu().data.numpy()

  results_file_path = os.path.join(save_dir, f'gc_results_{0.016 + 0.008 * (1+i)}.txt')
  with open(results_file_path, 'w') as f:
    f.write(f'True variable usage = {100 * np.mean(GC)}%\n')
    f.write(f'Estimated variable usage = {100 * np.mean(GC_est)}%\n')
    f.write(f'Accuracy = {100 * np.mean(GC == GC_est)}%\n')
    f.write(f'True positives = {np.sum((GC == 1) & (GC_est == 1))}\n')
    f.write(f'True negatives = {np.sum((GC == 0) & (GC_est == 0))}\n')
    f.write(f'False positives = {np.sum((GC == 0) & (GC_est == 1))}\n')
    f.write(f'False negatives = {np.sum((GC == 1) & (GC_est == 0))}\n')

  # Make figures for Granger causality matrices
  fig, axarr = plt.subplots(1, 2, figsize=(16, 5))
  axarr[0].imshow(GC, cmap='Blues')
  axarr[0].set_title('GC actual')
  axarr[0].set_ylabel('Affected series')
  axarr[0].set_xlabel('Causal series')
  axarr[0].set_xticks([])
  axarr[0].set_yticks([])

  axarr[1].imshow(GC_est, cmap='Blues', vmin=0, vmax=1, extent=(0, len(GC_est), len(GC_est), 0))
  axarr[1].set_title('GC estimated')
  axarr[1].set_ylabel('Affected series')
  axarr[1].set_xlabel('Causal series')
  axarr[1].set_xticks([])
  axarr[1].set_yticks([])

  # Mark disagreements
  for i in range(len(GC_est)):
    for j in range(len(GC_est)):
        if GC[i, j] != GC_est[i, j]:
            rect = plt.Rectangle((j, i-0.05), 1, 1, facecolor='none', edgecolor='red', linewidth=1)
            axarr[1].add_patch(rect)

  gc_plot_path = os.path.join(save_dir, f'gc_plot_{0.016 + 0.008 * (1+i)}.png')
  plt.savefig(gc_plot_path)  # Save the GC plot to Google Drive
  plt.close()  # Close the plot to prevent it from displaying
# Out:
# ----------Iter = 50----------
# Loss = 0.588079
# Variable usage = 100.00%
# ----------Iter = 100----------
# Loss = 0.581923
# Variable usage = 100.00%
# ----------Iter = 150----------
# Loss = 0.575875
# Variable usage = 100.00%
# ----------Iter = 200----------
# Loss = 0.569836
# Variable usage = 100.00%
# ----------Iter = 250----------
# Loss = 0.563805
# Variable usage = 100.00%
# ----------Iter = 300----------
# Loss = 0.557779
# Variable usage = 100.00%
# ----------Iter = 350----------
# Loss = 0.551759
# Variable usage = 100.00%
# ----------Iter = 400----------
# Loss = 0.545744
# Variable usage = 100.00%
# ----------Iter = 450----------
# Loss = 0.539735
# Variable usage = 100.00%
# ----------Iter = 500----------
# Loss = 0.533730
# Variable usage = 100.00%
# ----------Iter = 550----------
# Loss = 0.527729
# Variable usage = 100.00%
# ----------Iter = 600----------
# Loss = 0.521733
# Variable usage = 100.00%
# ----------Iter = 650----------
# Loss = 0.515740
# Variable usage = 100.00%
# ----------Iter = 700----------
# Loss = 0.509751
# Variable usage = 100.00%
# ----------Iter = 750----------
# Loss = 0.503766
# Variable usage = 100.00%
# ----------Iter = 800----------
# Loss = 0.497784
# Variable usage = 100.00%
# ----------Iter = 850----------
# Loss = 0.491806
# Variable usage = 100.00%
# ----------Iter = 900----------
# Loss = 0.485830
# Variable usage = 100.00%
# ----------Iter = 950----------
# Loss = 0.479857
# Variable usage = 100.00%
# ----------Iter = 1000----------
# Loss = 0.473887
# Variable usage = 100.00%
# ----------Iter = 1050----------
# Loss = 0.467920
# Variable usage = 100.00%
# ----------Iter = 1100----------
# Loss = 0.461955
# Variable usage = 100.00%
# ----------Iter = 1150----------
# Loss = 0.455993
# Variable usage = 100.00%
# ----------Iter = 1200----------
# Loss = 0.450033
# Variable usage = 100.00%
# ----------Iter = 1250----------
# Loss = 0.444076
# Variable usage = 100.00%
# ----------Iter = 1300----------
# Loss = 0.438121
# Variable usage = 100.00%
# ----------Iter = 1350----------
# Loss = 0.432168
# Variable usage = 100.00%
# ----------Iter = 1400----------
# Loss = 0.426217
# Variable usage = 100.00%
# ----------Iter = 1450----------
# Loss = 0.420268
# Variable usage = 100.00%
# ----------Iter = 1500----------
# Loss = 0.414321
# Variable usage = 100.00%
# ----------Iter = 1550----------
# Loss = 0.408376
# Variable usage = 100.00%
# ----------Iter = 1600----------
# Loss = 0.402433
# Variable usage = 100.00%
# ----------Iter = 1650----------
# Loss = 0.396492
# Variable usage = 100.00%
# ----------Iter = 1700----------
# Loss = 0.390553
# Variable usage = 100.00%
# ----------Iter = 1750----------
# Loss = 0.384616
# Variable usage = 100.00%
# ----------Iter = 1800----------
# Loss = 0.378681
# Variable usage = 100.00%
# ----------Iter = 1850----------
# Loss = 0.372747
# Variable usage = 100.00%
# ----------Iter = 1900----------
# Loss = 0.366816
# Variable usage = 100.00%
# ----------Iter = 1950----------
# Loss = 0.360886
# Variable usage = 100.00%
# ----------Iter = 2000----------
# Loss = 0.354958
# Variable usage = 100.00%
# ----------Iter = 2050----------
# Loss = 0.349032
# Variable usage = 100.00%
# ----------Iter = 2100----------
# Loss = 0.343108
# Variable usage = 100.00%
# ----------Iter = 2150----------
# Loss = 0.337186
# Variable usage = 100.00%
# ----------Iter = 2200----------
# Loss = 0.331266
# Variable usage = 100.00%
# ----------Iter = 2250----------
# Loss = 0.325348
# Variable usage = 100.00%
# ----------Iter = 2300----------
# Loss = 0.319432
# Variable usage = 100.00%
# ----------Iter = 2350----------
# Loss = 0.313517
# Variable usage = 100.00%
# ----------Iter = 2400----------
# Loss = 0.307605
# Variable usage = 100.00%
# ----------Iter = 2450----------
# Loss = 0.301695
# Variable usage = 100.00%
# ----------Iter = 2500----------
# Loss = 0.295786
# Variable usage = 100.00%
# ----------Iter = 2550----------
# Loss = 0.289880
# Variable usage = 100.00%
# ----------Iter = 2600----------
# Loss = 0.283976
# Variable usage = 100.00%
# ----------Iter = 2650----------
# Loss = 0.278074
# Variable usage = 100.00%
# ----------Iter = 2700----------
# Loss = 0.272174
# Variable usage = 100.00%
# ----------Iter = 2750----------
# Loss = 0.266276
# Variable usage = 100.00%
# ----------Iter = 2800----------
# Loss = 0.260381
# Variable usage = 0.00%
# ----------Iter = 10600----------
# Loss = 0.078573
# Variable usage = 0.00%
# ----------Iter = 10650----------
# Loss = 0.078442
# Variable usage = 0.00%
# ----------Iter = 10700----------
# Loss = 0.078311
# Variable usage = 0.00%
# ----------Iter = 10750----------
# Loss = 0.078181
# Variable usage = 0.00%
# ----------Iter = 10800----------
# Loss = 0.078050
# Variable usage = 0.00%
# ----------Iter = 10850----------
# Loss = 0.077920
# Variable usage = 0.00%
# ----------Iter = 10900----------
# Loss = 0.077790
# Variable usage = 0.00%
# ----------Iter = 10950----------
# Loss = 0.077660
# Variable usage = 0.00%
# ----------Iter = 11000----------
# Loss = 0.077531
# Variable usage = 0.00%
# ----------Iter = 11050----------
# Loss = 0.077402
# Variable usage = 0.00%
# ----------Iter = 11100----------
# Loss = 0.077273
# Variable usage = 0.00%
# ----------Iter = 11150----------
# Loss = 0.077144
# Variable usage = 0.00%
# ----------Iter = 11200----------
# Loss = 0.077016
# Variable usage = 0.00%
# ----------Iter = 11250----------
# Loss = 0.076888
# Variable usage = 0.00%
# ----------Iter = 11300----------
# Loss = 0.076760
# Variable usage = 0.00%
# ----------Iter = 11350----------
# Loss = 0.076632
# Variable usage = 0.00%
# ----------Iter = 11400----------
# Loss = 0.076505
# Variable usage = 0.00%
# ----------Iter = 11450----------
# Loss = 0.076378
# Variable usage = 0.00%
# ----------Iter = 11500----------
# Loss = 0.076251
# Variable usage = 0.00%
# ----------Iter = 11550----------
# Loss = 0.076125
# Variable usage = 0.00%
# ----------Iter = 11600----------
# Loss = 0.075998
# Variable usage = 0.00%
# ----------Iter = 11650----------
# Loss = 0.075872
# Variable usage = 0.00%
# ----------Iter = 11700----------
# Loss = 0.075746
# Variable usage = 0.00%
# ----------Iter = 11750----------
# Loss = 0.075621
# Variable usage = 0.00%
# ----------Iter = 11800----------
# Loss = 0.075496
# Variable usage = 0.00%
# ----------Iter = 11850----------
# Loss = 0.075370
# Variable usage = 0.00%
# ----------Iter = 11900----------
# Loss = 0.075246
# Variable usage = 0.00%
# ----------Iter = 11950----------
# Loss = 0.075121
# Variable usage = 0.00%
# ----------Iter = 12000----------
# Loss = 0.074997
# Variable usage = 0.00%
# ----------Iter = 12050----------
# Loss = 0.074873
# Variable usage = 0.00%
# ----------Iter = 12100----------
# Loss = 0.074749
# Variable usage = 0.00%
# ----------Iter = 12150----------
# Loss = 0.074625
# Variable usage = 0.00%
# ----------Iter = 12200----------
# Loss = 0.074502
# Variable usage = 0.00%
# ----------Iter = 12250----------
# Loss = 0.074379
# Variable usage = 0.00%
# ----------Iter = 12300----------
# Loss = 0.074256
# Variable usage = 0.00%
# ----------Iter = 12350----------
# Loss = 0.074133
# Variable usage = 0.00%
# ----------Iter = 12400----------
# Loss = 0.074011
# Variable usage = 0.00%
# ----------Iter = 12450----------
# Loss = 0.073889
# Variable usage = 0.00%
# ----------Iter = 12500----------
# Loss = 0.073767
# Variable usage = 0.00%
# ----------Iter = 12550----------
# Loss = 0.073646
# Variable usage = 0.00%
# ----------Iter = 12600----------
# Loss = 0.073524
# Variable usage = 0.00%
# ----------Iter = 12650----------
# Loss = 0.073403
# Variable usage = 0.00%
# ----------Iter = 12700----------
# Loss = 0.073282
# Variable usage = 0.00%
# ----------Iter = 12750----------
# Loss = 0.073162
# Variable usage = 0.00%
# ----------Iter = 12800----------
# Loss = 0.073041
# Variable usage = 0.00%
# ----------Iter = 12850----------
# Loss = 0.072921
# Variable usage = 0.00%
# ----------Iter = 12900----------
# Loss = 0.072801
# Variable usage = 0.00%
# ----------Iter = 12950----------
# Loss = 0.072681
# Variable usage = 0.00%
# ----------Iter = 13000----------
# Loss = 0.072562
# Variable usage = 0.00%
# ----------Iter = 13050----------
# Loss = 0.072443
# Variable usage = 0.00%
# ----------Iter = 13100----------
# Loss = 0.072324
# Variable usage = 0.00%
# ----------Iter = 13150----------
# Loss = 0.072205
# Variable usage = 0.00%
# ----------Iter = 13200----------
# Loss = 0.072087
# Variable usage = 0.00%
# ----------Iter = 13250----------
# Loss = 0.071968
# Variable usage = 0.00%
# ----------Iter = 13300----------
# Loss = 0.071850
# Variable usage = 0.00%
# ----------Iter = 13350----------
# Loss = 0.071732
# Variable usage = 0.00%
# ----------Iter = 13400----------
# Loss = 0.071615
# Variable usage = 0.00%
# ----------Iter = 13450----------
# Loss = 0.071498
# Variable usage = 0.00%
# ----------Iter = 13500----------
# Loss = 0.071381
# Variable usage = 0.00%
# ----------Iter = 13550----------
# Loss = 0.071264
# Variable usage = 0.00%
# ----------Iter = 13600----------
# Loss = 0.071147
# Variable usage = 0.00%
# ----------Iter = 13650----------
# Loss = 0.071031
# Variable usage = 0.00%
# ----------Iter = 13700----------
# Loss = 0.070915
# Variable usage = 0.00%
# ----------Iter = 13750----------
# Loss = 0.070799
# Variable usage = 0.00%
# ----------Iter = 13800----------
# Loss = 0.070683
# Variable usage = 0.00%
# ----------Iter = 13850----------
# Loss = 0.070568
# Variable usage = 0.00%
# ----------Iter = 13900----------
# Loss = 0.070452
# Variable usage = 0.00%
# ----------Iter = 13950----------
# Loss = 0.070337
# Variable usage = 0.00%
# ----------Iter = 14000----------
# Loss = 0.070223
# Variable usage = 0.00%
# ----------Iter = 14050----------
# Loss = 0.070108
# Variable usage = 0.00%
# ----------Iter = 14100----------
# Loss = 0.069994
# Variable usage = 0.00%
# ----------Iter = 14150----------
# Loss = 0.069880
# Variable usage = 0.00%
# ----------Iter = 14200----------
# Loss = 0.069766
# Variable usage = 0.00%
# ----------Iter = 14250----------
# Loss = 0.069652
# Variable usage = 0.00%
# ----------Iter = 14300----------
# Loss = 0.069539
# Variable usage = 0.00%
# ----------Iter = 14350----------
# Loss = 0.069426
# Variable usage = 0.00%
# ----------Iter = 14400----------
# Loss = 0.069313
# Variable usage = 0.00%
# ----------Iter = 14450----------
# Loss = 0.069200
# Variable usage = 0.00%
# ----------Iter = 14500----------
# Loss = 0.069087
# Variable usage = 0.00%
# ----------Iter = 14550----------
# Loss = 0.068975
# Variable usage = 0.00%
# ----------Iter = 14600----------
# Loss = 0.068863
# Variable usage = 0.00%
# ----------Iter = 14650----------
# Loss = 0.068751
# Variable usage = 0.00%
# ----------Iter = 14700----------
# Loss = 0.068640
# Variable usage = 0.00%
# ----------Iter = 14750----------
# Loss = 0.068528
# Variable usage = 0.00%
# ----------Iter = 14800----------
# Loss = 0.068417
# Variable usage = 0.00%
# ----------Iter = 14850----------
# Loss = 0.068306
# Variable usage = 0.00%
# ----------Iter = 14900----------
# Loss = 0.068196
# Variable usage = 0.00%
# ----------Iter = 14950----------
# Loss = 0.068085
# Variable usage = 0.00%
# ----------Iter = 15000----------
# Loss = 0.067975
# Variable usage = 0.00%
# ----------Iter = 15050----------
# Loss = 0.067865
# Variable usage = 0.00%
# ----------Iter = 15100----------
# Loss = 0.067755
# Variable usage = 0.00%
# ----------Iter = 15150----------
# Loss = 0.067645
# Variable usage = 0.00%
# ----------Iter = 15200----------
# Loss = 0.067536
# Variable usage = 0.00%
# ----------Iter = 15250----------
# Loss = 0.067427
# Variable usage = 0.00%
# ----------Iter = 15300----------
# Loss = 0.067318
# Variable usage = 0.00%
# ----------Iter = 15350----------
# Loss = 0.067209
# Variable usage = 0.00%
# ----------Iter = 15400----------
# Loss = 0.067101
# Variable usage = 0.00%
# ----------Iter = 15450----------
# Loss = 0.066992
# Variable usage = 0.00%
# ----------Iter = 15500----------
# Loss = 0.066884
# Variable usage = 0.00%
# ----------Iter = 15550----------
# Loss = 0.066777
# Variable usage = 0.00%
# ----------Iter = 15600----------
# Loss = 0.066669
# Variable usage = 0.00%
# ----------Iter = 15650----------
# Loss = 0.066561
# Variable usage = 0.00%
# ----------Iter = 15700----------
# Loss = 0.066454
# Variable usage = 0.00%
# ----------Iter = 15750----------
# Loss = 0.066347
# Variable usage = 0.00%
# ----------Iter = 15800----------
# Loss = 0.066240
# Variable usage = 0.00%
# ----------Iter = 15850----------
# Loss = 0.066134
# Variable usage = 0.00%
# ----------Iter = 15900----------
# Loss = 0.066028
# Variable usage = 0.00%
# ----------Iter = 15950----------
# Loss = 0.065921
# Variable usage = 0.00%
# ----------Iter = 16000----------
# Loss = 0.065815
# Variable usage = 0.00%
# ----------Iter = 16050----------
# Loss = 0.065710
# Variable usage = 0.00%
# ----------Iter = 16100----------
# Loss = 0.065604
# Variable usage = 0.00%
# ----------Iter = 16150----------
# Loss = 0.065499
# Variable usage = 0.00%
# ----------Iter = 16200----------
# Loss = 0.065394
# Variable usage = 0.00%
# ----------Iter = 16250----------
# Loss = 0.065289
# Variable usage = 0.00%
# ----------Iter = 16300----------
# Loss = 0.065184
# Variable usage = 0.00%
# ----------Iter = 16350----------
# Loss = 0.065080
# Variable usage = 0.00%
# ----------Iter = 16400----------
# Loss = 0.064976
# Variable usage = 0.00%
# ----------Iter = 16450----------
# Loss = 0.064871
# Variable usage = 0.00%
# ----------Iter = 16500----------
# Loss = 0.064768
# Variable usage = 0.00%
# ----------Iter = 16550----------
# Loss = 0.064664
# Variable usage = 0.00%
# ----------Iter = 16600----------
# Loss = 0.064561
# Variable usage = 0.00%
# ----------Iter = 16650----------
# Loss = 0.064457
# Variable usage = 0.00%
# ----------Iter = 16700----------
# Loss = 0.064354
# Variable usage = 0.00%
# ----------Iter = 16750----------
# Loss = 0.064252
# Variable usage = 0.00%
# ----------Iter = 16800----------
# Loss = 0.064149
# Variable usage = 0.00%
# ----------Iter = 16850----------
# Loss = 0.064047
# Variable usage = 0.00%
# ----------Iter = 16900----------
# Loss = 0.063944
# Variable usage = 0.00%
# ----------Iter = 16950----------
# Loss = 0.063842
# Variable usage = 0.00%
# ----------Iter = 17000----------
# Loss = 0.063741
# Variable usage = 0.00%
# ----------Iter = 17050----------
# Loss = 0.063639
# Variable usage = 0.00%
# ----------Iter = 17100----------
# Loss = 0.063538
# Variable usage = 0.00%
# ----------Iter = 17150----------
# Loss = 0.063436
# Variable usage = 0.00%
# ----------Iter = 17200----------
# Loss = 0.063336
# Variable usage = 0.00%
# ----------Iter = 17250----------
# Loss = 0.063235
# Variable usage = 0.00%
# ----------Iter = 17300----------
# Loss = 0.063134
# Variable usage = 0.00%
# ----------Iter = 17350----------
# Loss = 0.063034
# Variable usage = 0.00%
# ----------Iter = 17400----------
# Loss = 0.062934
# Variable usage = 0.00%
# ----------Iter = 17450----------
# Loss = 0.062834
# Variable usage = 0.00%
# ----------Iter = 17500----------
# Loss = 0.062734
# Variable usage = 0.00%
# ----------Iter = 17550----------
# Loss = 0.062634
# Variable usage = 0.00%
# ----------Iter = 17600----------
# Loss = 0.062535
# Variable usage = 0.00%
# ----------Iter = 17650----------
# Loss = 0.062436
# Variable usage = 0.00%
# ----------Iter = 17700----------
# Loss = 0.062337
# Variable usage = 0.00%
# ----------Iter = 17750----------
# Loss = 0.062238
# Variable usage = 0.00%
# ----------Iter = 17800----------
# Loss = 0.062139
# Variable usage = 0.00%
# ----------Iter = 17850----------
# Loss = 0.062041
# Variable usage = 0.00%
# ----------Iter = 17900----------
# Loss = 0.061943
# Variable usage = 0.00%
# ----------Iter = 17950----------
# Loss = 0.061845
# Variable usage = 0.00%
# ----------Iter = 18000----------
# Loss = 0.061747
# Variable usage = 0.00%
# ----------Iter = 18050----------
# Loss = 0.061650
# Variable usage = 0.00%
# ----------Iter = 18100----------
# Loss = 0.061552
# Variable usage = 0.00%
# ----------Iter = 18150----------
# Loss = 0.061455
# Variable usage = 0.00%
# ----------Iter = 18200----------
# Loss = 0.061358
# Variable usage = 0.00%
# ----------Iter = 18250----------
# Loss = 0.061261
# Variable usage = 0.00%
# ----------Iter = 18300----------
# Loss = 0.061165
# Variable usage = 0.00%
# ----------Iter = 18350----------
# Loss = 0.061068
# Variable usage = 0.00%
# ----------Iter = 18400----------
# Loss = 0.060972
# Variable usage = 0.00%
# ----------Iter = 18450----------
# Loss = 0.060876
# Variable usage = 0.00%
# ----------Iter = 18500----------
# Loss = 0.060780
# Variable usage = 0.00%
# ----------Iter = 18550----------
# Loss = 0.060684
# Variable usage = 0.00%
# ----------Iter = 18600----------
# Loss = 0.060589
# Variable usage = 0.00%
# ----------Iter = 18650----------
# Loss = 0.060494
# Variable usage = 0.00%
# ----------Iter = 18700----------
# Loss = 0.060398
# Variable usage = 0.00%
# ----------Iter = 18750----------
# Loss = 0.060304
# Variable usage = 0.00%
# ----------Iter = 18800----------
# Loss = 0.060209
# Variable usage = 0.00%
# ----------Iter = 18850----------
# Loss = 0.060114
# Variable usage = 0.00%
# ----------Iter = 18900----------
# Loss = 0.060020
# Variable usage = 0.00%
# ----------Iter = 18950----------
# Loss = 0.059926
# Variable usage = 0.00%
# ----------Iter = 19000----------
# Loss = 0.059832
# Variable usage = 0.00%
# ----------Iter = 19050----------
# Loss = 0.059738
# Variable usage = 0.00%
# ----------Iter = 19100----------
# Loss = 0.059645
# Variable usage = 0.00%
# ----------Iter = 19150----------
# Loss = 0.059551
# Variable usage = 0.00%
# ----------Iter = 19200----------
# Loss = 0.059458
# Variable usage = 0.00%
# ----------Iter = 19250----------
# Loss = 0.059365
# Variable usage = 0.00%
# ----------Iter = 19300----------
# Loss = 0.059272
# Variable usage = 0.00%
# ----------Iter = 19350----------
# Loss = 0.059179
# Variable usage = 0.00%
# ----------Iter = 19400----------
# Loss = 0.059087
# Variable usage = 0.00%
# ----------Iter = 19450----------
# Loss = 0.058995
# Variable usage = 0.00%
# ----------Iter = 19500----------
# Loss = 0.058903
# Variable usage = 0.00%
# ----------Iter = 19550----------
# Loss = 0.058811
# Variable usage = 0.00%
# ----------Iter = 19600----------
# Loss = 0.058719
# Variable usage = 0.00%
# ----------Iter = 19650----------
# Loss = 0.058627
# Variable usage = 0.00%
# ----------Iter = 19700----------
# Loss = 0.058536
# Variable usage = 0.00%
# ----------Iter = 19750----------
# Loss = 0.058445
# Variable usage = 0.00%
# ----------Iter = 19800----------
# Loss = 0.058354
# Variable usage = 0.00%
# ----------Iter = 19850----------
# Loss = 0.058263
# Variable usage = 0.00%
# ----------Iter = 19900----------
# Loss = 0.058172
# Variable usage = 0.00%
# ----------Iter = 19950----------
# Loss = 0.058082
# Variable usage = 0.00%
# ----------Iter = 20000----------
# Loss = 0.057992
# Variable usage = 0.00%
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-4e50c9d2e334> in <cell line: 1>()
#      14   # Loss function plot
#      15   plt.figure(figsize=(8, 5))
# ---> 16   train_loss_np = [loss.cpu().detach().numpy() for loss in train_loss_list]
#      17   plt.plot(50 * np.arange(len(train_loss_np)), train_loss_np)
#      18   plt.title('cGRU training')
#
# NameError: name 'train_loss_list' is not defined
